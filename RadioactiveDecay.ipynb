# %% [markdown]
# # Exercise 2.1 - Radioactive Decays
#
# 1. Graph the number of the remaining nuclei as a function of time for the following cases
#
# ### <center> $N_0 = 500$, $\alpha=4\cdot 10^{-5} s^{-1}$, timestep = $20 s$, timeEnd = $20000 s$ </center>
# ### <center> $N_0 = 500$, $\alpha=2\cdot 10^{-4} s^{-1}$, timestep = $20 s$, timeEnd = $20000 s$ </center>
# 2. Plot the number of decays that happen in 100 s for a sufficient amount of simulations

# %%
import sys
import ROOT
import datetime
import RadioactiveDecay
# Out:
# Welcome to JupyROOT 6.16/00

# %%
sample001 = RadioactiveDecay.Sample(500,4e-5)
sample002 = RadioactiveDecay.Sample(500,2e-4)
samples = [sample001, sample002]

# %%
experiment = RadioactiveDecay.Experiment(samples,20,20000)
experiment.simulate()

# %% [markdown]
# ## 1.

# %%
 experiment.PlotDecayVsTime(semilogy=False)

# %% [markdown]
# ## 2.

# %%
# This takes quite some time...
experiment.simulate()
experiment.PlotDecaysInInterval(100,1000)
# Out:
# Running simulation number: 0/1000
# Running simulation number: 50/1000
# Running simulation number: 100/1000
# Running simulation number: 150/1000
# Running simulation number: 200/1000
# Running simulation number: 250/1000
# Running simulation number: 300/1000
# Running simulation number: 350/1000
# Running simulation number: 400/1000
# Running simulation number: 450/1000
# Running simulation number: 500/1000
# Running simulation number: 550/1000
# Running simulation number: 600/1000
# Running simulation number: 650/1000
# Running simulation number: 700/1000
# Running simulation number: 750/1000
# Running simulation number: 800/1000
# Running simulation number: 850/1000
# Running simulation number: 900/1000
# Running simulation number: 950/1000
